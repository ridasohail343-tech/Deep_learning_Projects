# %% [markdown]
# <a href="https://colab.research.google.com/github/ridasohail343-tech/Deep_learning_Projects/blob/main/SentimentalAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.datasets import imdb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(x_train, maxlen=100, padding="post")
x_test= pad_sequences(x_test, maxlen=100, padding="post")

# %%
model=Sequential()
model.add(Embedding(10000,1))
model.add(SimpleRNN(32, input_shape=(100, 1)))
model.add(Dense(1, activation="sigmoid"))
model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ...

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - acc: 0.5298 - loss: 0.6895 - val_acc: 0.6058 - val_loss: 0.6608
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - acc: 0.6538 - loss: 0.6215 - val_acc: 0.6000 - val_loss: 0.6499
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - acc: 0.6563 - loss: 0.6129 - val_acc: 0.6327 - val_loss: 0.6220
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - acc: 0.7342 - loss: 0.5298 - val_acc: 0.7382 - val_loss: 0.5330
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - acc: 0.7384 - loss: 0.5353 - val_acc: 0.7020 - val_loss: 0.5610

# %%
predict=model.predict(x_test)
print(predict)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# [[0.5854307 ]
#  [0.49811974]
#  [0.49811974]
#  ...
#  [0.5714937 ]
#  [0.43158057]
#  [0.49811974]]

# %%
# !git init
# !git add .
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git commit -m "Add sentiment analysis RNN model"
# Out:
# [master (root-commit) 842ce86] Add sentiment analysis RNN model
#  21 files changed, 51090 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#  create mode 100644 .config/logs/2026.09.04/13.24.04.448016.log
#  create mode 100644 .config/logs/2026.09.04/13.24.31.709670.log
#  create mode 100644 .config/logs/2026.09.04/13.24.48.959800.log
#  create mode 100644 .config/logs/2026.09.04/13.24.51.717993.log
#  create mode 100644 .config/logs/2026.09.04/13.25.09.479018.log
#  create mode 100644 .config/logs/2026.09.04/13.25.10.757956.log
# ...

# %%
# !git config --global user.name "ridasohail343-tech"
# !git config --global user.email "ridasohail343@gmail.com"
